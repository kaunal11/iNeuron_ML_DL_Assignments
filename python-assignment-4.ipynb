# %% [markdown]
# #**1.1 Write a Python Program(with class concepts) to find the area of the triangle using the formula: area = (s*(s-a)*(s-b)*(s-c)) ** 0.5. Function to take the length of the sides of triangle from user should be defined in the parent class and function to calculate the area should be defined in subclass.**#

# %%
import math
class Triangle:
    def __init__(self, a, b, c):
        self.a=a
        self.b=b
        self.c=c
    def area(self):
        s=(self.a+self.b+self.c)/2
        area=math.sqrt(s*(s-self.a)*(s-self.b)*(s-self.c))
        return area

# %%
t1=Triangle(4,13,15)
print ('area = ',t1.area())
# Out:
# area =  24.0

# %% [markdown]
# # **1.2 Write a function filter_long_words() that takes a list of words and an integer n and returns the list of words that are longer than n.**

# %%
def filter_long_words(lst,n):
    long_words=[]
    for word in lst:
        if len(word)>n:
            long_words.append(word)
    return long_words

# %%
filter_long_words(['Learning','Classroom','Machine','is','to','the','data','science'],2)
# Out:
# ['Learning', 'Classroom', 'Machine', 'the', 'data', 'science']

# %% [markdown]
# # **2.1 Write a Python program using function concept that maps list of words into a list of integers representing the lengths of the corresponding words.**
#
# **Hint: If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4] Here 2,3 and 4 are the lengths of the words in the list.**

# %%
def map_length(lst):
    length_list=[]
    for word in lst:
        length_list.append(len(word))
    return length_list

# %%
map_length(['Learning','Classroom','Machine','is','to','the','data','science'])
# Out:
# [8, 9, 7, 2, 2, 3, 4, 7]

# %% [markdown]
# # **2.2 Write a Python function which takes a character (i.e. a string of length 1) and returns True if it is a vowel, False otherwise.**

# %%
vowels=['a','e','i','o','u']
def is_vowel(s):
    if s in vowels:
        return True
    else:
        return False

# %%
is_vowel('z')
# Out:
# False
